# %% [markdown]
# <a href="https://colab.research.google.com/github/dennismingming/hackerrank/blob/master/Day_3_Intro_to_Conditional_Statements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    N = int(input().strip())
    if N % 2 != 0 or N in range(6,21):
        print('Weird')
    elif N in range(2,6) or 20 < N:
        print('Not Weird')
